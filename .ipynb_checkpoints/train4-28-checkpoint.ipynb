# %%
import os
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
import cv2
import numpy as np
import matplotlib.pyplot as plt
plt.style.use("ggplot")
from skimage.transform import resize
import keras
from keras import backend as K
import tensorflow as tf

from tqdm import tqdm_notebook

from keras.models import Model, load_model
from keras.layers import Input, BatchNormalization, Activation, Dense, Dropout
from keras.layers.core import Lambda, RepeatVector, Reshape
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D, GlobalMaxPool2D
from keras.layers import AveragePooling2D
from keras.layers.merge import concatenate, add
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from keras import initializers
# Out:
# Using TensorFlow backend.

# %%
im_width = 480
im_height = 240
path_train = 'cancer_3/train/'
path_valid = 'cancer_3/valid/'
path_test = 'cancer_3/test/'
path_delete = 'cancer_3/delete/'
SEED = 42

# %%
def get_data(path, train=True):
    ids = next(os.walk(path + "/images/image/"))[2]  # 获取path+images目录下的所有文件名
    X = np.zeros((len(ids), im_width, im_height, 1), dtype=np.float32)
    if train:
        y = np.zeros((len(ids), im_width, im_height, 1), dtype=np.float32)
    print('Getting and resizing images ... ')
    for n, id_ in enumerate(ids):
        # Load images
        img = cv2.imread(path + '/images/image/' + id_, cv2.IMREAD_GRAYSCALE)
        x_img = resize(img, (im_width, im_height, 1), mode='constant', preserve_range=True)
        #x_img = np.reshape(x_img, (im_width, im_height, 1))

        # Load masks
        if train:
            mask = cv2.imread(path + '/masks/mask/' + id_, cv2.IMREAD_GRAYSCALE)
            mask = resize(mask, (im_width, im_height, 1), mode='constant', preserve_range=True)
            #mask = np.reshape(mask, (im_width, im_height, 1))

        # Save images
        X[n, ..., 0] = x_img.squeeze() / 255
        if train:
            y[n] = mask / 255
    print('Done!')
    if train:
        return X, y
    else:
        return X


x_data, y_data = get_data(path_train, train=True)
# Out:
# Getting and resizing images ...
# Done!

# %%
batch_size = 8


def get_train_test_augmented(X_data=x_data, Y_data=y_data, validation_split=0.2, batch_size=batch_size, seed=SEED):
    X_train, X_test, Y_train, Y_test = train_test_split(X_data,
                                                        Y_data,
                                                        train_size=1 - validation_split,
                                                        test_size=validation_split,
                                                        random_state=seed)
    # Image data generator distortion options
    data_gen_args = dict(rotation_range=10.,
                         horizontal_flip=True,
                         vertical_flip=True,
                         fill_mode='nearest')  # use 'constant'??

    # Train data, provide the same seed and keyword arguments to the fit and flow methods
    X_datagen = ImageDataGenerator(**data_gen_args)
    Y_datagen = ImageDataGenerator(**data_gen_args)
    X_datagen.fit(X_train, augment=True, seed=seed)
    Y_datagen.fit(Y_train, augment=True, seed=seed)
    X_train_augmented = X_datagen.flow(X_train, batch_size=batch_size, shuffle=True, seed=seed)
    Y_train_augmented = Y_datagen.flow(Y_train, batch_size=batch_size, shuffle=True, seed=seed)

    # Test data, no data augmentation, but we create a generator anyway
    X_datagen_val = ImageDataGenerator()
    Y_datagen_val = ImageDataGenerator()
    X_datagen_val.fit(X_test, augment=True, seed=seed)
    Y_datagen_val.fit(Y_test, augment=True, seed=seed)
    X_test_augmented = X_datagen_val.flow(X_test, batch_size=batch_size, shuffle=True, seed=seed)
    Y_test_augmented = Y_datagen_val.flow(Y_test, batch_size=batch_size, shuffle=True, seed=seed)

    # combine generators into one which yields image and masks
    train_generator = zip(X_train_augmented, Y_train_augmented)
    test_generator = zip(X_test_augmented, Y_test_augmented)

    return train_generator, test_generator, X_train, X_test, Y_train, Y_test

# %%
from sklearn.model_selection import train_test_split
train_generator, test_generator, X_train, X_val, Y_train, Y_val = get_train_test_augmented(X_data=x_data, Y_data=y_data, validation_split=0.2, batch_size=batch_size)

# %%
def mean_iou(y_true, y_pred):
    prec = []
    for t in np.arange(0.5, 1.0, 0.05):
        y_pred_ = tf.to_int32(y_pred > t)
        score, up_opt = tf.metrics.mean_iou(y_true, y_pred_, 2)
        K.get_session().run(tf.local_variables_initializer())
        with tf.control_dependencies([up_opt]):
            score = tf.identity(score)
        prec.append(score)
    return K.mean(K.stack(prec), axis=0)


def dice_coef(y_true, y_pred):
    smooth = 1.
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)


def bce_dice_loss(y_true, y_pred):
    return 0.5 * keras.losses.binary_crossentropy(y_true, y_pred) - dice_coef(y_true, y_pred)

# %%
from keras.layers import UpSampling2D, multiply
from keras.layers import AveragePooling2D

def BatchActivate(x):
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    return x

def conv2d_block(input_tensor, n_filters, kernel_size=3, batchnorm=True):
    # first layer
    x = Conv2D(filters=n_filters, kernel_size=(kernel_size, kernel_size), kernel_initializer="he_normal",
               bias_initializer='zeros',padding="same")(input_tensor)#initializers.random_normal(stddev=0.01)
    if batchnorm:
        x = BatchNormalization()(x)
    x = Activation("relu")(x)
    # second layer
    x = Conv2D(filters=n_filters, kernel_size=(kernel_size, kernel_size), kernel_initializer="he_normal",
               bias_initializer='zeros',padding="same")(x)
    if batchnorm:
        x = BatchNormalization()(x)
    x = Activation("relu")(x)
    return x

def DenseBlock(channels,inputs):

    inputs = BatchActivate(inputs)
    conv1 = Conv2D(channels, (3, 3), kernel_initializer="he_normal",
               bias_initializer='zeros', padding='same')(inputs)

    conv2 =BatchActivate(conv1)
    conv2 = Conv2D(channels//4, (3, 3), kernel_initializer="he_normal",
               bias_initializer='zeros', padding='same')(conv2)

    concat1 = concatenate([conv1,conv2])

    conv3 = BatchActivate(concat1)
    conv3 = Conv2D(channels // 4, (3, 3), kernel_initializer="he_normal",
                   bias_initializer='zeros', padding='same')(conv3)

    concat2 = concatenate([conv1, conv2,conv3])

    conv4 = BatchActivate(concat2)
    conv4 = Conv2D(channels//4, (3, 3), kernel_initializer="he_normal",
               bias_initializer='zeros', padding='same')(conv4)

    concat3 = concatenate([conv1,conv2,conv3,conv4])

    conv5 = BatchActivate(concat3)
    conv5 = Conv2D(channels // 4, (3, 3), kernel_initializer="he_normal",
                   bias_initializer='zeros', padding='same')(conv5)

    result = concatenate([conv1,conv2,conv3,conv4,conv5])
    return result


def dense_unet(input_img, n_filters=32, dropout=0.6, batchnorm=True):
    # contracting path
    c1 = Conv2D(n_filters*1, (3, 3), kernel_initializer="he_normal",
                   bias_initializer='zeros', padding='same')(input_img)
    c1 = DenseBlock(n_filters*1,c1)
    c1_1 = Conv2D(n_filters*1, (1, 1), kernel_initializer="he_normal",
                   bias_initializer='zeros', padding='same')(c1)
    p1 = AveragePooling2D((2, 2))(c1_1)
    #p1 = Dropout(0.5)(p1)

    c2 = DenseBlock(n_filters*2,p1)
    c2_1 = Conv2D(n_filters*2, (1, 1), kernel_initializer="he_normal",
                   bias_initializer='zeros', padding='same')(c2)
    p2 = AveragePooling2D((2, 2))(c2_1)
    p2 = Dropout(0.6)(p2)

    c3 = DenseBlock(n_filters*4,p2)
    c3_1 = Conv2D(n_filters*4, (1, 1), kernel_initializer="he_normal",
                   bias_initializer='zeros', padding='same')(c3)
    p3 = AveragePooling2D((2, 2))(c3_1)
    p3 = Dropout(0.6)(p3)

    c4 = DenseBlock(n_filters*8,p3)
    c4_1 = Conv2D(n_filters*8, (1, 1), kernel_initializer="he_normal",
                   bias_initializer='zeros', padding='same')(c4)
    p4 = AveragePooling2D((2, 2))(c4_1)
    p4 = Dropout(0.6)(p4)

    c5 = DenseBlock(n_filters*8,p4)

    # expansive path
    u6 = Conv2DTranspose(n_filters * 8, (3, 3), strides=(2, 2), padding='same')(c5)
    u6 = Activation("relu")(u6)
    u6 = concatenate([u6, c4])
    u6 = Dropout(dropout)(u6)
    c6 = conv2d_block(u6, n_filters=n_filters * 8, kernel_size=3, batchnorm=batchnorm)

    u7 = Conv2DTranspose(n_filters * 4, (3, 3), strides=(2, 2), padding='same')(c6)
    u7 = Activation("relu")(u7)
    u7 = concatenate([u7, c3])
    u7 = Dropout(dropout)(u7)
    c7 = conv2d_block(u7, n_filters=n_filters * 4, kernel_size=3, batchnorm=batchnorm)

    u8 = Conv2DTranspose(n_filters * 2, (3, 3), strides=(2, 2), padding='same')(c7)
    u8 = Activation("relu")(u8)
    u8 = concatenate([u8, c2])
    u8 = Dropout(dropout)(u8)
    c8 = conv2d_block(u8, n_filters=n_filters * 2, kernel_size=3, batchnorm=batchnorm)

    u9 = Conv2DTranspose(n_filters * 1, (3, 3), strides=(2, 2), padding='same')(c8)
    u9 = Activation("relu")(u9)
    u9 = concatenate([u9, c1], axis=3)
    u9 = Dropout(dropout)(u9)
    c9 = conv2d_block(u9, n_filters=n_filters * 1, kernel_size=3, batchnorm=batchnorm)

    outputs = Conv2D(1, (1, 1), activation='sigmoid')(c9)
    model = Model(inputs=[input_img], outputs=[outputs])
    return model

# %%
input_img = Input((im_width, im_height, 1), name='img')
model = dense_unet(input_img, n_filters=32, dropout=0.6, batchnorm=True)

model.compile(optimizer=Adam(0.001),loss=bce_dice_loss, metrics=[dice_coef] )#  loss="binary_crossentropy", metrics=["accuracy"]
model.summary()


callbacks = [
    EarlyStopping(patience=20, verbose=1),
    ReduceLROnPlateau(factor=0.1, patience=3, min_lr=0.00001, verbose=1),
    ModelCheckpoint('model-breast11_4-28.h5', verbose=1, save_best_only=True, save_weights_only=False)
]
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# img (InputLayer)                (None, 480, 240, 1)  0
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 480, 240, 32) 320         img[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 480, 240, 32) 128         conv2d_40[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 480, 240, 32) 0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 480, 240, 32) 9248        activation_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 480, 240, 32) 128         conv2d_41[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 480, 240, 32) 0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 480, 240, 8)  2312        activation_35[0][0]
# __________________________________________________________________________________________________
# concatenate_25 (Concatenate)    (None, 480, 240, 40) 0           conv2d_41[0][0]
#                                                                  conv2d_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 480, 240, 40) 160         concatenate_25[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 480, 240, 40) 0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 480, 240, 8)  2888        activation_36[0][0]
# __________________________________________________________________________________________________
# concatenate_26 (Concatenate)    (None, 480, 240, 48) 0           conv2d_41[0][0]
#                                                                  conv2d_42[0][0]
#                                                                  conv2d_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 480, 240, 48) 192         concatenate_26[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 480, 240, 48) 0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 480, 240, 8)  3464        activation_37[0][0]
# __________________________________________________________________________________________________
# concatenate_27 (Concatenate)    (None, 480, 240, 56) 0           conv2d_41[0][0]
#                                                                  conv2d_42[0][0]
#                                                                  conv2d_43[0][0]
#                                                                  conv2d_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 480, 240, 56) 224         concatenate_27[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 480, 240, 56) 0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 480, 240, 8)  4040        activation_38[0][0]
# __________________________________________________________________________________________________
# concatenate_28 (Concatenate)    (None, 480, 240, 64) 0           conv2d_41[0][0]
#                                                                  conv2d_42[0][0]
#                                                                  conv2d_43[0][0]
#                                                                  conv2d_44[0][0]
#                                                                  conv2d_45[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 480, 240, 32) 2080        concatenate_28[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_5 (AveragePoo (None, 240, 120, 32) 0           conv2d_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 240, 120, 32) 128         average_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 240, 120, 32) 0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 240, 120, 64) 18496       activation_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 240, 120, 64) 256         conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 240, 120, 64) 0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 240, 120, 16) 9232        activation_40[0][0]
# __________________________________________________________________________________________________
# concatenate_29 (Concatenate)    (None, 240, 120, 80) 0           conv2d_47[0][0]
#                                                                  conv2d_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 240, 120, 80) 320         concatenate_29[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 240, 120, 80) 0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 240, 120, 16) 11536       activation_41[0][0]
# __________________________________________________________________________________________________
# concatenate_30 (Concatenate)    (None, 240, 120, 96) 0           conv2d_47[0][0]
#                                                                  conv2d_48[0][0]
#                                                                  conv2d_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 240, 120, 96) 384         concatenate_30[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 240, 120, 96) 0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 240, 120, 16) 13840       activation_42[0][0]
# __________________________________________________________________________________________________
# concatenate_31 (Concatenate)    (None, 240, 120, 112 0           conv2d_47[0][0]
#                                                                  conv2d_48[0][0]
#                                                                  conv2d_49[0][0]
#                                                                  conv2d_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 240, 120, 112 448         concatenate_31[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 240, 120, 112 0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 240, 120, 16) 16144       activation_43[0][0]
# __________________________________________________________________________________________________
# concatenate_32 (Concatenate)    (None, 240, 120, 128 0           conv2d_47[0][0]
#                                                                  conv2d_48[0][0]
#                                                                  conv2d_49[0][0]
#                                                                  conv2d_50[0][0]
#                                                                  conv2d_51[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 240, 120, 64) 8256        concatenate_32[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_6 (AveragePoo (None, 120, 60, 64)  0           conv2d_52[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 120, 60, 64)  0           average_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 120, 60, 64)  256         dropout_8[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 120, 60, 64)  0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 120, 60, 128) 73856       activation_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 120, 60, 128) 512         conv2d_53[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 120, 60, 128) 0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 120, 60, 32)  36896       activation_45[0][0]
# __________________________________________________________________________________________________
# concatenate_33 (Concatenate)    (None, 120, 60, 160) 0           conv2d_53[0][0]
#                                                                  conv2d_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 120, 60, 160) 640         concatenate_33[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 120, 60, 160) 0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 120, 60, 32)  46112       activation_46[0][0]
# __________________________________________________________________________________________________
# concatenate_34 (Concatenate)    (None, 120, 60, 192) 0           conv2d_53[0][0]
#                                                                  conv2d_54[0][0]
#                                                                  conv2d_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 120, 60, 192) 768         concatenate_34[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 120, 60, 192) 0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 120, 60, 32)  55328       activation_47[0][0]
# __________________________________________________________________________________________________
# concatenate_35 (Concatenate)    (None, 120, 60, 224) 0           conv2d_53[0][0]
#                                                                  conv2d_54[0][0]
#                                                                  conv2d_55[0][0]
#                                                                  conv2d_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 120, 60, 224) 896         concatenate_35[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 120, 60, 224) 0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 120, 60, 32)  64544       activation_48[0][0]
# __________________________________________________________________________________________________
# concatenate_36 (Concatenate)    (None, 120, 60, 256) 0           conv2d_53[0][0]
#                                                                  conv2d_54[0][0]
#                                                                  conv2d_55[0][0]
#                                                                  conv2d_56[0][0]
#                                                                  conv2d_57[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 120, 60, 128) 32896       concatenate_36[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_7 (AveragePoo (None, 60, 30, 128)  0           conv2d_58[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 60, 30, 128)  0           average_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 60, 30, 128)  512         dropout_9[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 60, 30, 128)  0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 60, 30, 256)  295168      activation_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 60, 30, 256)  1024        conv2d_59[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 60, 30, 256)  0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 60, 30, 64)   147520      activation_50[0][0]
# __________________________________________________________________________________________________
# concatenate_37 (Concatenate)    (None, 60, 30, 320)  0           conv2d_59[0][0]
#                                                                  conv2d_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 60, 30, 320)  1280        concatenate_37[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 60, 30, 320)  0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 60, 30, 64)   184384      activation_51[0][0]
# __________________________________________________________________________________________________
# concatenate_38 (Concatenate)    (None, 60, 30, 384)  0           conv2d_59[0][0]
#                                                                  conv2d_60[0][0]
#                                                                  conv2d_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 60, 30, 384)  1536        concatenate_38[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 60, 30, 384)  0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 60, 30, 64)   221248      activation_52[0][0]
# __________________________________________________________________________________________________
# concatenate_39 (Concatenate)    (None, 60, 30, 448)  0           conv2d_59[0][0]
#                                                                  conv2d_60[0][0]
#                                                                  conv2d_61[0][0]
#                                                                  conv2d_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 60, 30, 448)  1792        concatenate_39[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 60, 30, 448)  0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 60, 30, 64)   258112      activation_53[0][0]
# __________________________________________________________________________________________________
# concatenate_40 (Concatenate)    (None, 60, 30, 512)  0           conv2d_59[0][0]
#                                                                  conv2d_60[0][0]
#                                                                  conv2d_61[0][0]
#                                                                  conv2d_62[0][0]
#                                                                  conv2d_63[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 60, 30, 256)  131328      concatenate_40[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_8 (AveragePoo (None, 30, 15, 256)  0           conv2d_64[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 30, 15, 256)  0           average_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 30, 15, 256)  1024        dropout_10[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 30, 15, 256)  0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 30, 15, 256)  590080      activation_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 30, 15, 256)  1024        conv2d_65[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 30, 15, 256)  0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 30, 15, 64)   147520      activation_55[0][0]
# __________________________________________________________________________________________________
# concatenate_41 (Concatenate)    (None, 30, 15, 320)  0           conv2d_65[0][0]
#                                                                  conv2d_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 30, 15, 320)  1280        concatenate_41[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 30, 15, 320)  0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 30, 15, 64)   184384      activation_56[0][0]
# __________________________________________________________________________________________________
# concatenate_42 (Concatenate)    (None, 30, 15, 384)  0           conv2d_65[0][0]
#                                                                  conv2d_66[0][0]
#                                                                  conv2d_67[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 30, 15, 384)  1536        concatenate_42[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 30, 15, 384)  0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 30, 15, 64)   221248      activation_57[0][0]
# __________________________________________________________________________________________________
# concatenate_43 (Concatenate)    (None, 30, 15, 448)  0           conv2d_65[0][0]
#                                                                  conv2d_66[0][0]
#                                                                  conv2d_67[0][0]
#                                                                  conv2d_68[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 30, 15, 448)  1792        concatenate_43[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 30, 15, 448)  0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 30, 15, 64)   258112      activation_58[0][0]
# __________________________________________________________________________________________________
# concatenate_44 (Concatenate)    (None, 30, 15, 512)  0           conv2d_65[0][0]
#                                                                  conv2d_66[0][0]
#                                                                  conv2d_67[0][0]
#                                                                  conv2d_68[0][0]
#                                                                  conv2d_69[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_5 (Conv2DTrans (None, 60, 30, 256)  1179904     concatenate_44[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 60, 30, 256)  0           conv2d_transpose_5[0][0]
# __________________________________________________________________________________________________
# concatenate_45 (Concatenate)    (None, 60, 30, 768)  0           activation_59[0][0]
#                                                                  concatenate_40[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 60, 30, 768)  0           concatenate_45[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, 60, 30, 256)  1769728     dropout_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 60, 30, 256)  1024        conv2d_70[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 60, 30, 256)  0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 60, 30, 256)  590080      activation_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 60, 30, 256)  1024        conv2d_71[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 60, 30, 256)  0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_6 (Conv2DTrans (None, 120, 60, 128) 295040      activation_61[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 120, 60, 128) 0           conv2d_transpose_6[0][0]
# __________________________________________________________________________________________________
# concatenate_46 (Concatenate)    (None, 120, 60, 384) 0           activation_62[0][0]
#                                                                  concatenate_36[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 120, 60, 384) 0           concatenate_46[0][0]
# __________________________________________________________________________________________________
# conv2d_72 (Conv2D)              (None, 120, 60, 128) 442496      dropout_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 120, 60, 128) 512         conv2d_72[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 120, 60, 128) 0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# conv2d_73 (Conv2D)              (None, 120, 60, 128) 147584      activation_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 120, 60, 128) 512         conv2d_73[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 120, 60, 128) 0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_7 (Conv2DTrans (None, 240, 120, 64) 73792       activation_64[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 240, 120, 64) 0           conv2d_transpose_7[0][0]
# __________________________________________________________________________________________________
# concatenate_47 (Concatenate)    (None, 240, 120, 192 0           activation_65[0][0]
#                                                                  concatenate_32[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 240, 120, 192 0           concatenate_47[0][0]
# __________________________________________________________________________________________________
# conv2d_74 (Conv2D)              (None, 240, 120, 64) 110656      dropout_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 240, 120, 64) 256         conv2d_74[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 240, 120, 64) 0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, 240, 120, 64) 36928       activation_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 240, 120, 64) 256         conv2d_75[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 240, 120, 64) 0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_8 (Conv2DTrans (None, 480, 240, 32) 18464       activation_67[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 480, 240, 32) 0           conv2d_transpose_8[0][0]
# __________________________________________________________________________________________________
# concatenate_48 (Concatenate)    (None, 480, 240, 96) 0           activation_68[0][0]
#                                                                  concatenate_28[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 480, 240, 96) 0           concatenate_48[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, 480, 240, 32) 27680       dropout_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 480, 240, 32) 128         conv2d_76[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 480, 240, 32) 0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, 480, 240, 32) 9248        activation_69[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 480, 240, 32) 128         conv2d_77[0][0]
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, 480, 240, 32) 0           batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# conv2d_78 (Conv2D)              (None, 480, 240, 1)  33          activation_70[0][0]
# ==================================================================================================
# Total params: 7,774,305
# Trainable params: 7,763,265
# Non-trainable params: 11,040
# __________________________________________________________________________________________________

# %%
H = model.fit_generator(train_generator, 
                    validation_data=test_generator, 
                    validation_steps=len(X_val)/batch_size, 
                    steps_per_epoch=len(X_train)/(batch_size),
                    epochs=100,
                    callbacks=callbacks)
# Out:
# Epoch 1/100
# 32/32 [==============================] - 27s 857ms/step - loss: 0.0471 - dice_coef: 0.1274 - val_loss: 7.6190 - val_dice_coef: 0.0646
#
# Epoch 00001: val_loss improved from inf to 7.61901, saving model to model-breast11_4-28.h5
# Epoch 2/100
# 32/32 [==============================] - 13s 413ms/step - loss: -0.1283 - dice_coef: 0.2316 - val_loss: 7.6327 - val_dice_coef: 0.0638
#
# Epoch 00002: val_loss did not improve from 7.61901
# Epoch 3/100
# 32/32 [==============================] - 13s 414ms/step - loss: -0.2086 - dice_coef: 0.2945 - val_loss: 5.7008 - val_dice_coef: 0.0645
#
# Epoch 00003: val_loss improved from 7.61901 to 5.70081, saving model to model-breast11_4-28.h5
# Epoch 4/100
# 32/32 [==============================] - 13s 413ms/step - loss: -0.2799 - dice_coef: 0.3499 - val_loss: 7.5835 - val_dice_coef: 0.0665
#
# Epoch 00004: val_loss did not improve from 5.70081
# Epoch 5/100
# 32/32 [==============================] - 13s 413ms/step - loss: -0.2892 - dice_coef: 0.3620 - val_loss: 7.2760 - val_dice_coef: 0.0561
#
# Epoch 00005: val_loss did not improve from 5.70081
# Epoch 6/100
# 32/32 [==============================] - 13s 413ms/step - loss: -0.3664 - dice_coef: 0.4301 - val_loss: 3.6730 - val_dice_coef: 0.1022
#
# Epoch 00006: val_loss improved from 5.70081 to 3.67303, saving model to model-breast11_4-28.h5
# Epoch 7/100
# 32/32 [==============================] - 13s 413ms/step - loss: -0.3770 - dice_coef: 0.4389 - val_loss: 2.5937 - val_dice_coef: 0.1354
#
# Epoch 00007: val_loss improved from 3.67303 to 2.59365, saving model to model-breast11_4-28.h5
# Epoch 8/100
# 32/32 [==============================] - 13s 413ms/step - loss: -0.3885 - dice_coef: 0.4565 - val_loss: 0.9905 - val_dice_coef: 0.1728
#
# Epoch 00008: val_loss improved from 2.59365 to 0.99054, saving model to model-breast11_4-28.h5
# Epoch 9/100
# 32/32 [==============================] - 13s 413ms/step - loss: -0.4255 - dice_coef: 0.4888 - val_loss: 0.8606 - val_dice_coef: 0.1786
#
# Epoch 00009: val_loss improved from 0.99054 to 0.86061, saving model to model-breast11_4-28.h5
# Epoch 10/100
# 32/32 [==============================] - 13s 413ms/step - loss: -0.3609 - dice_coef: 0.4324 - val_loss: 1.2043 - val_dice_coef: 0.1945
#
# Epoch 00010: val_loss did not improve from 0.86061
# Epoch 11/100
# 32/32 [==============================] - 13s 412ms/step - loss: -0.3969 - dice_coef: 0.4642 - val_loss: 0.9868 - val_dice_coef: 0.1806
#
# Epoch 00011: val_loss did not improve from 0.86061
# Epoch 12/100
# 32/32 [==============================] - 13s 413ms/step - loss: -0.4173 - dice_coef: 0.4848 - val_loss: 0.4455 - val_dice_coef: 0.2264
#
# Epoch 00012: val_loss improved from 0.86061 to 0.44554, saving model to model-breast11_4-28.h5
# Epoch 13/100
# 32/32 [==============================] - 13s 414ms/step - loss: -0.4090 - dice_coef: 0.4754 - val_loss: 1.6524 - val_dice_coef: 0.1449
#
# Epoch 00013: val_loss did not improve from 0.44554
# Epoch 14/100
# 32/32 [==============================] - 13s 412ms/step - loss: -0.4189 - dice_coef: 0.4862 - val_loss: 0.2902 - val_dice_coef: 0.2016
#
# Epoch 00014: val_loss improved from 0.44554 to 0.29020, saving model to model-breast11_4-28.h5
# Epoch 15/100
# 32/32 [==============================] - 13s 413ms/step - loss: -0.4857 - dice_coef: 0.5440 - val_loss: -0.0210 - val_dice_coef: 0.3423
#
# Epoch 00015: val_loss improved from 0.29020 to -0.02100, saving model to model-breast11_4-28.h5
# Epoch 16/100
# 32/32 [==============================] - 13s 413ms/step - loss: -0.4229 - dice_coef: 0.4895 - val_loss: 0.3812 - val_dice_coef: 0.2273
#
# Epoch 00016: val_loss did not improve from -0.02100
# Epoch 17/100
# 32/32 [==============================] - 13s 413ms/step - loss: -0.4646 - dice_coef: 0.5297 - val_loss: -0.5035 - val_dice_coef: 0.5718
#
# Epoch 00017: val_loss improved from -0.02100 to -0.50348, saving model to model-breast11_4-28.h5
# Epoch 18/100
# 32/32 [==============================] - 13s 414ms/step - loss: -0.4629 - dice_coef: 0.5263 - val_loss: -0.1336 - val_dice_coef: 0.2257
#
# Epoch 00018: val_loss did not improve from -0.50348
# Epoch 19/100
# 32/32 [==============================] - 13s 413ms/step - loss: -0.4728 - dice_coef: 0.5352 - val_loss: -0.0383 - val_dice_coef: 0.2940
#
# Epoch 00019: val_loss did not improve from -0.50348
# Epoch 20/100
# 32/32 [==============================] - 13s 412ms/step - loss: -0.4656 - dice_coef: 0.5292 - val_loss: -0.0181 - val_dice_coef: 0.3287
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00020: val_loss did not improve from -0.50348
# Epoch 21/100
# 32/32 [==============================] - 13s 413ms/step - loss: -0.4978 - dice_coef: 0.5564 - val_loss: -0.5040 - val_dice_coef: 0.5600
#
# Epoch 00021: val_loss improved from -0.50348 to -0.50399, saving model to model-breast11_4-28.h5
# Epoch 22/100
# 32/32 [==============================] - 13s 413ms/step - loss: -0.5069 - dice_coef: 0.5641 - val_loss: -0.5219 - val_dice_coef: 0.5746
#
# Epoch 00022: val_loss improved from -0.50399 to -0.52186, saving model to model-breast11_4-28.h5
# Epoch 23/100
# 32/32 [==============================] - 13s 413ms/step - loss: -0.4990 - dice_coef: 0.5578 - val_loss: -0.3898 - val_dice_coef: 0.4658
#
# Epoch 00023: val_loss did not improve from -0.52186
# Epoch 24/100
# 32/32 [==============================] - 13s 412ms/step - loss: -0.5034 - dice_coef: 0.5654 - val_loss: -0.4695 - val_dice_coef: 0.5234
#
# Epoch 00024: val_loss did not improve from -0.52186
# Epoch 25/100
# 32/32 [==============================] - 13s 413ms/step - loss: -0.4908 - dice_coef: 0.5472 - val_loss: -0.4483 - val_dice_coef: 0.5114
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 00025: val_loss did not improve from -0.52186
# Epoch 26/100
# 32/32 [==============================] - 13s 412ms/step - loss: -0.5171 - dice_coef: 0.5754 - val_loss: -0.5063 - val_dice_coef: 0.5563
#
# Epoch 00026: val_loss did not improve from -0.52186
# Epoch 27/100
# 32/32 [==============================] - 13s 413ms/step - loss: -0.5001 - dice_coef: 0.5572 - val_loss: -0.4974 - val_dice_coef: 0.5515
#
# Epoch 00027: val_loss did not improve from -0.52186
# Epoch 28/100
# 32/32 [==============================] - 13s 413ms/step - loss: -0.5232 - dice_coef: 0.5781 - val_loss: -0.5380 - val_dice_coef: 0.5872
#
# Epoch 00028: val_loss improved from -0.52186 to -0.53804, saving model to model-breast11_4-28.h5
# Epoch 29/100
# 32/32 [==============================] - 13s 412ms/step - loss: -0.5201 - dice_coef: 0.5777 - val_loss: -0.5129 - val_dice_coef: 0.5638
#
# Epoch 00029: val_loss did not improve from -0.53804
# Epoch 30/100
# 32/32 [==============================] - 13s 412ms/step - loss: -0.5188 - dice_coef: 0.5725 - val_loss: -0.5665 - val_dice_coef: 0.6078
#
# Epoch 00030: val_loss improved from -0.53804 to -0.56649, saving model to model-breast11_4-28.h5
# Epoch 31/100
# 32/32 [==============================] - 13s 413ms/step - loss: -0.4858 - dice_coef: 0.5471 - val_loss: -0.5626 - val_dice_coef: 0.6049
#
# Epoch 00031: val_loss did not improve from -0.56649
# Epoch 32/100
# 32/32 [==============================] - 13s 413ms/step - loss: -0.5417 - dice_coef: 0.5904 - val_loss: -0.4959 - val_dice_coef: 0.5517
#
# Epoch 00032: val_loss did not improve from -0.56649
# Epoch 33/100
# 32/32 [==============================] - 13s 413ms/step - loss: -0.4829 - dice_coef: 0.5462 - val_loss: -0.5708 - val_dice_coef: 0.6182
#
# Epoch 00033: val_loss improved from -0.56649 to -0.57075, saving model to model-breast11_4-28.h5
# Epoch 34/100
# 32/32 [==============================] - 13s 412ms/step - loss: -0.5595 - dice_coef: 0.6067 - val_loss: -0.5062 - val_dice_coef: 0.5559
#
# Epoch 00034: val_loss did not improve from -0.57075
# Epoch 35/100
# 32/32 [==============================] - 13s 413ms/step - loss: -0.5112 - dice_coef: 0.5714 - val_loss: -0.5648 - val_dice_coef: 0.6076
#
# Epoch 00035: val_loss did not improve from -0.57075
# Epoch 36/100
# 32/32 [==============================] - 13s 413ms/step - loss: -0.5343 - dice_coef: 0.5884 - val_loss: -0.5501 - val_dice_coef: 0.6013
#
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 1e-05.
#
# Epoch 00036: val_loss did not improve from -0.57075
# Epoch 37/100
# 32/32 [==============================] - 13s 412ms/step - loss: -0.5160 - dice_coef: 0.5720 - val_loss: -0.5412 - val_dice_coef: 0.5924
#
# Epoch 00037: val_loss did not improve from -0.57075
# Epoch 38/100
# 32/32 [==============================] - 13s 413ms/step - loss: -0.5256 - dice_coef: 0.5836 - val_loss: -0.4877 - val_dice_coef: 0.5380
#
# Epoch 00038: val_loss did not improve from -0.57075
# Epoch 39/100
# 32/32 [==============================] - 13s 413ms/step - loss: -0.5263 - dice_coef: 0.5794 - val_loss: -0.5465 - val_dice_coef: 0.5931
#
# Epoch 00039: val_loss did not improve from -0.57075
# Epoch 40/100
# 32/32 [==============================] - 13s 413ms/step - loss: -0.4994 - dice_coef: 0.5596 - val_loss: -0.5625 - val_dice_coef: 0.6077
#
# Epoch 00040: val_loss did not improve from -0.57075
# Epoch 41/100
# 32/32 [==============================] - 13s 413ms/step - loss: -0.5119 - dice_coef: 0.5717 - val_loss: -0.5488 - val_dice_coef: 0.5988
#
# Epoch 00041: val_loss did not improve from -0.57075
# Epoch 42/100
# 32/32 [==============================] - 13s 412ms/step - loss: -0.5483 - dice_coef: 0.5961 - val_loss: -0.5416 - val_dice_coef: 0.5837
#
# Epoch 00042: val_loss did not improve from -0.57075
# Epoch 43/100
# 32/32 [==============================] - 13s 413ms/step - loss: -0.5147 - dice_coef: 0.5732 - val_loss: -0.5395 - val_dice_coef: 0.5927
#
# Epoch 00043: val_loss did not improve from -0.57075
# Epoch 44/100
# 32/32 [==============================] - 13s 413ms/step - loss: -0.5124 - dice_coef: 0.5673 - val_loss: -0.5419 - val_dice_coef: 0.5929
#
# Epoch 00044: val_loss did not improve from -0.57075
# Epoch 45/100
# 32/32 [==============================] - 13s 412ms/step - loss: -0.4865 - dice_coef: 0.5480 - val_loss: -0.5533 - val_dice_coef: 0.6043
#
# Epoch 00045: val_loss did not improve from -0.57075
# Epoch 46/100
# 32/32 [==============================] - 13s 412ms/step - loss: -0.5633 - dice_coef: 0.6136 - val_loss: -0.5340 - val_dice_coef: 0.5809
#
# Epoch 00046: val_loss did not improve from -0.57075
# Epoch 47/100
# 32/32 [==============================] - 13s 413ms/step - loss: -0.4777 - dice_coef: 0.5347 - val_loss: -0.5098 - val_dice_coef: 0.5625
#
# Epoch 00047: val_loss did not improve from -0.57075
# Epoch 48/100
# 32/32 [==============================] - 13s 414ms/step - loss: -0.5177 - dice_coef: 0.5759 - val_loss: -0.5488 - val_dice_coef: 0.5956
#
# Epoch 00048: val_loss did not improve from -0.57075
# Epoch 49/100
# 32/32 [==============================] - 13s 412ms/step - loss: -0.5322 - dice_coef: 0.5852 - val_loss: -0.5263 - val_dice_coef: 0.5781
#
# Epoch 00049: val_loss did not improve from -0.57075
# Epoch 50/100
# 32/32 [==============================] - 13s 413ms/step - loss: -0.5526 - dice_coef: 0.6041 - val_loss: -0.5067 - val_dice_coef: 0.5582
#
# Epoch 00050: val_loss did not improve from -0.57075
# Epoch 51/100
# 32/32 [==============================] - 13s 412ms/step - loss: -0.5060 - dice_coef: 0.5662 - val_loss: -0.5741 - val_dice_coef: 0.6213
#
# Epoch 00051: val_loss improved from -0.57075 to -0.57411, saving model to model-breast11_4-28.h5
# Epoch 52/100
# 32/32 [==============================] - 13s 413ms/step - loss: -0.5414 - dice_coef: 0.5940 - val_loss: -0.5459 - val_dice_coef: 0.5925
#
# Epoch 00052: val_loss did not improve from -0.57411
# Epoch 53/100
# 32/32 [==============================] - 13s 413ms/step - loss: -0.5003 - dice_coef: 0.5574 - val_loss: -0.5128 - val_dice_coef: 0.5690
#
# Epoch 00053: val_loss did not improve from -0.57411
# Epoch 54/100
# 32/32 [==============================] - 13s 413ms/step - loss: -0.5394 - dice_coef: 0.5925 - val_loss: -0.5869 - val_dice_coef: 0.6338
#
# Epoch 00054: val_loss improved from -0.57411 to -0.58689, saving model to model-breast11_4-28.h5
# Epoch 55/100
# 32/32 [==============================] - 13s 413ms/step - loss: -0.5266 - dice_coef: 0.5804 - val_loss: -0.5062 - val_dice_coef: 0.5513
#
# Epoch 00055: val_loss did not improve from -0.58689
# Epoch 56/100
# 32/32 [==============================] - 13s 413ms/step - loss: -0.5201 - dice_coef: 0.5789 - val_loss: -0.5282 - val_dice_coef: 0.5811
#
# Epoch 00056: val_loss did not improve from -0.58689
# Epoch 57/100
# 32/32 [==============================] - 13s 413ms/step - loss: -0.5290 - dice_coef: 0.5842 - val_loss: -0.5666 - val_dice_coef: 0.6125
#
# Epoch 00057: val_loss did not improve from -0.58689
# Epoch 58/100
# 32/32 [==============================] - 13s 413ms/step - loss: -0.5018 - dice_coef: 0.5587 - val_loss: -0.5197 - val_dice_coef: 0.5744
#
# Epoch 00058: val_loss did not improve from -0.58689
# Epoch 59/100
# 32/32 [==============================] - 13s 413ms/step - loss: -0.5450 - dice_coef: 0.5961 - val_loss: -0.5893 - val_dice_coef: 0.6327
#
# Epoch 00059: val_loss improved from -0.58689 to -0.58931, saving model to model-breast11_4-28.h5
# Epoch 60/100
# 32/32 [==============================] - 13s 413ms/step - loss: -0.5401 - dice_coef: 0.5952 - val_loss: -0.5017 - val_dice_coef: 0.5505
#
# Epoch 00060: val_loss did not improve from -0.58931
# Epoch 61/100
# 32/32 [==============================] - 13s 412ms/step - loss: -0.5312 - dice_coef: 0.5857 - val_loss: -0.5571 - val_dice_coef: 0.6005
#
# Epoch 00061: val_loss did not improve from -0.58931
# Epoch 62/100
# 32/32 [==============================] - 13s 413ms/step - loss: -0.5042 - dice_coef: 0.5618 - val_loss: -0.5238 - val_dice_coef: 0.5755
#
# Epoch 00062: val_loss did not improve from -0.58931
# Epoch 63/100
# 32/32 [==============================] - 13s 413ms/step - loss: -0.5221 - dice_coef: 0.5782 - val_loss: -0.5283 - val_dice_coef: 0.5789
#
# Epoch 00063: val_loss did not improve from -0.58931
# Epoch 64/100
# 32/32 [==============================] - 13s 413ms/step - loss: -0.5118 - dice_coef: 0.5703 - val_loss: -0.5767 - val_dice_coef: 0.6234
#
# Epoch 00064: val_loss did not improve from -0.58931
# Epoch 65/100
# 32/32 [==============================] - 13s 413ms/step - loss: -0.5100 - dice_coef: 0.5684 - val_loss: -0.4995 - val_dice_coef: 0.5578
#
# Epoch 00065: val_loss did not improve from -0.58931
# Epoch 66/100
# 32/32 [==============================] - 13s 412ms/step - loss: -0.5239 - dice_coef: 0.5799 - val_loss: -0.5720 - val_dice_coef: 0.6173
#
# Epoch 00066: val_loss did not improve from -0.58931
# Epoch 67/100
# 32/32 [==============================] - 13s 413ms/step - loss: -0.5289 - dice_coef: 0.5838 - val_loss: -0.5328 - val_dice_coef: 0.5828
#
# Epoch 00067: val_loss did not improve from -0.58931
# Epoch 68/100
# 32/32 [==============================] - 13s 413ms/step - loss: -0.5422 - dice_coef: 0.5970 - val_loss: -0.5025 - val_dice_coef: 0.5562
#
# Epoch 00068: val_loss did not improve from -0.58931
# Epoch 69/100
# 32/32 [==============================] - 13s 413ms/step - loss: -0.5310 - dice_coef: 0.5835 - val_loss: -0.5631 - val_dice_coef: 0.6111
#
# Epoch 00069: val_loss did not improve from -0.58931
# Epoch 70/100
# 32/32 [==============================] - 13s 412ms/step - loss: -0.5410 - dice_coef: 0.5916 - val_loss: -0.5623 - val_dice_coef: 0.6092
#
# Epoch 00070: val_loss did not improve from -0.58931
# Epoch 71/100
# 32/32 [==============================] - 13s 413ms/step - loss: -0.5270 - dice_coef: 0.5811 - val_loss: -0.5054 - val_dice_coef: 0.5547
#
# Epoch 00071: val_loss did not improve from -0.58931
# Epoch 72/100
# 32/32 [==============================] - 13s 413ms/step - loss: -0.5079 - dice_coef: 0.5685 - val_loss: -0.5175 - val_dice_coef: 0.5670
#
# Epoch 00072: val_loss did not improve from -0.58931
# Epoch 73/100
# 32/32 [==============================] - 13s 413ms/step - loss: -0.5050 - dice_coef: 0.5608 - val_loss: -0.5466 - val_dice_coef: 0.5936
#
# Epoch 00073: val_loss did not improve from -0.58931
# Epoch 74/100
# 32/32 [==============================] - 13s 413ms/step - loss: -0.5340 - dice_coef: 0.5922 - val_loss: -0.5390 - val_dice_coef: 0.5933
#
# Epoch 00074: val_loss did not improve from -0.58931
# Epoch 75/100
# 32/32 [==============================] - 13s 412ms/step - loss: -0.5121 - dice_coef: 0.5694 - val_loss: -0.5256 - val_dice_coef: 0.5726
#
# Epoch 00075: val_loss did not improve from -0.58931
# Epoch 76/100
# 32/32 [==============================] - 13s 412ms/step - loss: -0.5193 - dice_coef: 0.5768 - val_loss: -0.5421 - val_dice_coef: 0.5964
#
# Epoch 00076: val_loss did not improve from -0.58931
# Epoch 77/100
# 32/32 [==============================] - 13s 413ms/step - loss: -0.5444 - dice_coef: 0.5968 - val_loss: -0.5396 - val_dice_coef: 0.5860
#
# Epoch 00077: val_loss did not improve from -0.58931
# Epoch 78/100
# 32/32 [==============================] - 13s 413ms/step - loss: -0.5044 - dice_coef: 0.5635 - val_loss: -0.5134 - val_dice_coef: 0.5612
#
# Epoch 00078: val_loss did not improve from -0.58931
# Epoch 79/100
# 32/32 [==============================] - 13s 413ms/step - loss: -0.4943 - dice_coef: 0.5503 - val_loss: -0.5454 - val_dice_coef: 0.5965
#
# Epoch 00079: val_loss did not improve from -0.58931
# Epoch 00079: early stopping

# %%
print(H.history.keys())
plt.plot(H.history['dice_coef'])
plt.plot(H.history['val_dice_coef'])
plt.title('model dice_coef')
plt.ylabel('dice_coef')
plt.xlabel('epoch')
plt.legend(['train', 'valid'], loc='upper left')
plt.savefig("accuracy4-28.png")
# Out:
# dict_keys(['val_loss', 'val_dice_coef', 'loss', 'dice_coef', 'lr'])

# %%
plt.plot(H.history['loss'])
plt.plot(H.history['val_loss'])
plt.title('model bce_dice_loss')
plt.ylabel('bce_dice_loss')
plt.xlabel('epoch')
plt.legend(['train', 'valid'], loc='upper left')
plt.savefig("loss4-28.png")
